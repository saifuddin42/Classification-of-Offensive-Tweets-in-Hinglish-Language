# %% [markdown]
# # Importing Libraries and Dependencies

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_latest_p36/bin/python -m pip install --upgrade pip' command.

# %%
from collections import Counter
import numpy as np
import pandas as pd
import nltk
import re
from nltk.corpus import stopwords
import fuzzywuzzy
from fuzzywuzzy import fuzz
from  nltk import word_tokenize
import torch.optim as optim
import torch
from torch import nn
from torch.autograd import Variable
import torch.nn.functional as F
import io
import utils
# Out:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# %%capture
# !pip install fasttext
import fasttext
import fasttext.util

# %%
# !nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Setting Cuda

# %%
cuda = torch.device("cuda:0" if torch.cuda.is_available() else 'cpu')

torch.manual_seed(42)

# %%
cuda
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Function Definitions

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
def get_processed_tokens_for_english_tweets(f):
    # preprocessing english tweets.
    #ingesting english csv file
    df = pd.read_csv(f,names = ['source','comment','annotation'],encoding='UTF-8')
    df['comment'] = df.comment.str.strip()   # removing spaces
    comments = np.asarray(df['comment'])    # dividing the dataframe into comments and tags and converting to array
    tags = np.asarray(df['annotation'])
    print((len(comments)))
    print(len(tags))
    stop_words = set(stopwords.words('english'))  #english stop words list
    processed_tokens = []
    for comment in comments:
    # comment = "Also see ....hw ur RSS activist caught in Burkha .... throwing beef in d holy temples...https://www.google.co.in/amp/www.india.com/news/india/burkha-clad-rss-activist-caught-throwing-beef-at-temple-pictures-go-viral-on-facebook-593154/amp/,NAGfacebook_corpus_msr_403402,On the death of 2 jawans in LOC CROSS FIRING"
        comment = comment.lower()   #lower casing each tweets
        Digit_REMOVAL = re.sub(r'[0-9]+', '',comment) #removal of numbers 
        URL_REMOVAL = re.sub(r"http\S+", "", Digit_REMOVAL) # removal of URLS
        tokenizer = nltk.RegexpTokenizer(r"\w+")   # removal of punctuation and tokenizing
        new_words = tokenizer.tokenize(URL_REMOVAL)
        sentence = []
        for word in new_words:
            if word not in stop_words:           #checking for stop words on each sentence
                sentence.append(word)
        processed_tokens.append(sentence)
    return processed_tokens, tags

# %%
#-----------------For hinglish dataset

def get_processed_hindi_tokens():
    Hindi_text  = "hindi/agr_hi_dev.csv"
    df1 = pd.read_csv(Hindi_text,names = ['source','comment','annotation'],encoding='UTF-8')
    df1['comment'] = df1.comment.str.strip()   # removing spaces
    hindi_comments = np.asarray(df1['comment'])    # dividing the dataframe into comments and tags and converting to array
    hindi_tags = np.asarray(df1['annotation'])
    print((hindi_comments[1])) 
    processed_Hindi_tokens = []
    for comment in hindi_comments:
    #   comment = "Also see ....hw ur RSS activist caught in Burkha .... throwing beef in d holy temples...https://www.google.co.in/amp/www.india.com/news/india/burkha-clad-rss-activist-caught-throwing-beef-at-temple-pictures-go-viral-on-facebook-593154/amp/,NAGfacebook_corpus_msr_403402,On the death of 2 jawans in LOC CROSS FIRING"
        comment = comment.lower()   #lower casing each tweets
        Digit_REMOVAL = re.sub(r'[0-9]+', '',comment) #removal of numbers 
        URL_REMOVAL = re.sub(r"http\S+", "", Digit_REMOVAL) # removal of URLS
        Emoji_removal = remove_emoji(URL_REMOVAL)
        if (isEnglish(Emoji_removal) == True):
            Emoji_removal = re.sub(r'[^\w\s]','',Emoji_removal)# removal of punctuation and tokenizing
        processed_Hindi_tokens.append(word_tokenize(Emoji_removal))
    print(processed_Hindi_tokens[0])
    return processed_Hindi_tokens

# %%
#-----------Transliteration and translation
def get_transliteration_Hinglish_Hindi_dict():
    transliteration_dict = "transliterations.hi-en.csv"
    t_dict = pd.read_csv(transliteration_dict,names = ['Hinglish','Hindi'],encoding='UTF-8',sep='\t')
    t_dict['Hinglish'] = t_dict['Hinglish'].str.strip()
    t_dict['Hindi'] = t_dict['Hindi'].str.strip()
    print(t_dict)
    t_dict = np.asarray(t_dict)
    print("After NP array")
    print(t_dict)
    return t_dict

#--------------profanity dictionary
def get_profanity_dict():
    profanity_dict = "ProfanityText.txt"
    P_dict = pd.read_csv(profanity_dict,names = ['Hinglish','English'],encoding='UTF-8',sep='\t')
    P_dict['Hinglish'] = P_dict['Hinglish'].str.strip()
    P_dict['English'] = P_dict['English'].str.strip()
    print("Profanity")
    print(P_dict)
    P_dict = np.asarray(P_dict)
    print("After NP array")
    print(P_dict)
    return P_dict

# %%
#------------------Translation of hindi text back to english-------
def translate_hindi_to_english():
    Hindi_dict = "Hindi_English_Dict.csv"
    H_dict = pd.read_csv(Hindi_dict,names = ['Hindi','English'],encoding='UTF-8')

    HE_dict_F = "HE_dictionary_functions.csv"
    H_dict_F = pd.read_csv(HE_dict_F,names = ['Hindi','English'],encoding='UTF-8')
    H_dict_F['Hindi'] = H_dict_F['Hindi'].str.strip()
    H_dict_F['English'] = H_dict_F['English'].str.strip()

    H_hindi_F = np.asarray(H_dict_F['Hindi'])
    H_english_F = np.asarray(H_dict_F['English'])

    H_dict['Hindi'] = H_dict['Hindi'].str.strip()
    H_dict['English'] = H_dict['English'].str.strip()

    H_hindi = np.asarray(H_dict['Hindi'])
    H_english = np.asarray(H_dict['English'])
    
    HE_dict = dict(zip(H_hindi,H_english))
    H_dict_F = dict(zip(H_hindi_F,H_english_F))

    EH_dict = {v:k for k, v in HE_dict.items()}
    EH_dict_F = {v:k for k, v in H_dict_F.items()}
    
    return HE_dict, H_dict_F, EH_dict, EH_dict_F

# %%
# Convert
def get_translated_hindi_english(HE_dict, H_dict_F):
    for i in range(0,len(processed_Hindi_tokens)):
        #print(i)
        for j in range (0,len(processed_Hindi_tokens[i])):
            Str = processed_Hindi_tokens[i][j]
            if(Str in HE_dict):
                processed_Hindi_tokens[i][j] = HE_dict[Str]
            elif(Str in H_dict_F):
                processed_Hindi_tokens[i][j] = H_dict_F[Str]
    print(processed_Hindi_tokens[0])
    return processed_Hindi_tokens

# %%
def get_token_translations(processed_tokens, processed_Hindi_tokens, EH_dict, P_dict, t_dict):
    for i in range(0,len(processed_Hindi_tokens)):
        for j in range (0,len(processed_Hindi_tokens[i])):
            flag = 0
            Str1 = (processed_Hindi_tokens[i][j])
            max_ratio = 60
            max_ratio_P = 75   #needs to be adjusted
            if (Str1 in EH_dict): # check whether the values exists in english dictionary or not.
                continue
            for l in range(0,len(P_dict)):
                Str2 = P_dict[l][0]
                Ratiostr1 = fuzz.ratio(Str1,Str2)
                if (Ratiostr1 >= max_ratio_P):
                    print(Ratiostr1)
                    max_ratio_P = Ratiostr1
                    flag = 1
                    print(processed_Hindi_tokens[i][j])
                    processed_Hindi_tokens[i][j] = P_dict[l][1]
                    print(f"{flag}-{processed_Hindi_tokens[i][j]}") 
                    break
            for p in EH_dict_F:
                Ratiostr1 = fuzz.ratio(Str1,str(p))
                if(Ratiostr1 >= 98):
                    flag = 1
                    break
            if (flag == 1):
                continue
            else:
                for k in range(0,len(t_dict)):
                    Str2 = t_dict[k][0]
                    Ratiostr1 = fuzz.ratio(Str1,Str2)
                    if (Ratiostr1 > max_ratio):
                        max_ratio = Ratiostr1
                        processed_Hindi_tokens[i][j] = t_dict[k][1]
    print(processed_Hindi_tokens[0])
    print(processed_Hindi_tokens[1])
    print(processed_tokens[12])
    return processed_Hindi_tokens

# %%
def translate_hindi_back_to_English(processed_Hindi_tokens, HE_dict, H_dict_F):
    for i in range(0,len(processed_Hindi_tokens)):
        print(i)
        for j in range (0,len(processed_Hindi_tokens[i])):
            Str = processed_Hindi_tokens[i][j]
            if(Str in HE_dict):
                processed_Hindi_tokens[i][j] = HE_dict[Str]
            elif(Str in H_dict_F):
                processed_Hindi_tokens[i][j] = H_dict_F[Str]
    return processed_Hindi_tokens

# %%
def load_vectors(fname):
    path = str(fname)
    fin = io.open(path, 'r', encoding='utf-8', newline='\n', errors='ignore')
    n, d = map(int, fin.readline().split())
    data = {}
    for line in fin:
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = map(float, tokens[1:])
    return data

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long).to(cuda)

def prepare_sequence_tags(seq, to_ix):
    idxs = to_ix[seq]
    idxs = torch.tensor(idxs, dtype=torch.long).to(cuda)
    idxs = idxs.view(1)
    return idxs

# %%
def sentence_to_padded_sentence(sentence, word_to_ix):
    
    # map sentences to vocab
    sentence =  [[word_to_ix[word] for word in sent] for sent in sentence]
    # sentence now looks like:  
    # [[1, 2, 3, 4, 5, 6, 7], [8, 8], [7, 9]]
    sentence_lengths = [len(sent) for sent in sentence]
    pad_token = word_to_ix['<PAD>']
    longest_sent = max(sentence_lengths)
    batch_size = len(sentence)
    padded_sentence = np.ones((batch_size, longest_sent)) * pad_token
    for i, x_len in enumerate(sentence_lengths):
        sequence = sentence[i]
        padded_sentence[i, 0:x_len] = sequence[:x_len]
    return padded_sentence

# %% [markdown]
# # Class Model

# %%
class MIMCT(nn.Module):   
    def __init__(self,input_channel,vocab_size,word_to_ix,output_channel,embedding_dim,hidden_dim,kernel_size,feature_linear, word_vector_list):
        super(MIMCT, self).__init__()
        
#         self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
#         self.word_embeddings.weight.data.copy_(torch.from_numpy(word_vector_list))
        self.word_embeddings = nn.Embedding.from_pretrained(torch.from_numpy(word_vector_list))
        
        self.CNN_Layers = nn.Sequential( 
            nn.Conv1d(input_channel, output_channel,kernel_size[0], stride=1),
            nn.Conv1d(input_channel, output_channel, kernel_size[1], stride=1),
            nn.Conv1d(input_channel, output_channel, kernel_size[2], stride=1),
            nn.Flatten(),nn.Dropout(p=0.25),
            nn.Linear(feature_linear, 64),
            nn.ReLU(),
            nn.Linear(64, 3),
            nn.Softmax()
            )
        
        
        #create LSTM.
        #self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)
        self.hidden2tag = nn.Linear(hidden_dim,3)
        self.dropout = nn.Dropout(p=0.20)
        self.softmax = nn.Softmax()
        self.sigmoid = nn.Sigmoid()
        self.maxpool = nn.MaxPool1d(kernel_size=3, stride=1)
        self.linear = nn.Linear(50+1,3)
    def forward(self,x):
      #  y = self.LSTM_Layers(x)
#         print(x)
        embeds = self.word_embeddings(x)
#         embeds = embeds.type(torch.DoubleTensor)
        embeds= embeds.float()
        embeds_cnn = embeds.view(1,embeds.size(0),embeds.size(1))
        cnn_output = self.CNN_Layers(embeds_cnn)
        
        lstm_out, _ = self.lstm(embeds.view(len(x), 1, -1))
        lstm_out= self.dropout(lstm_out)
        tag_space = self.hidden2tag(lstm_out.view(len(x), -1))
        
        lstm_output = self.sigmoid(tag_space)
        #concat the outputs the compile layer with categorical cross-entropy the loss function,
        lstm_output = lstm_output.view(lstm_output.size(0),-1)
        cnn_output = cnn_output.view(cnn_output.size(0),-1)
        X = torch.cat((lstm_output,cnn_output))
        X = X.view(1,X.size(0),X.size(1))
        X = self.maxpool(X)
        X = self.linear(X.view(X.size(2), -1))
        X = self.softmax(X)
#         print(X)
        return X

# %% [markdown]
# # Importing FastText English Word Embeddings

# %%
fasttext.util.download_model('en', if_exists='ignore')
ft = fasttext.load_model('cc.en.300.bin')
ft.get_dimension()
fasttext.util.reduce_model(ft, 200)
ft.get_dimension()

# %%
english_embeddings_fasttext = ft.get_words()

# %% [markdown]
# # English Part

# %%
f = "english/agr_en_train.csv"
processed_tokens, tags = get_processed_tokens_for_english_tweets(f)
print("1.\tProcessed tokens and Tags Generated!")

word_to_ix = {}
ix_to_word = {}
tag_to_ix = {}
ix_to_tag = {}
word_to_ix = {"<PAD>":0}

data_vector = dict()
word_vector_list = []

#For PAD
dummy_list = []
dummy_list = np.zeros(200, dtype = float)
word_vector_list.append(dummy_list)

for i, word in enumerate(english_embeddings_fasttext):
    word_to_ix[word] = len(word_to_ix)
    word_vector_list.append(list(ft.get_word_vector(word)))
for tag in tags:
    if tag not in tag_to_ix:
        tag_to_ix[tag] = len(tag_to_ix)
        ix_to_tag[tag_to_ix[tag]] = tag
        
word_vector_list = np.asarray(word_vector_list)
print("2.\tWord Vector List Created!")

training_data = utils.substitute_with_UNK_for_TEST(processed_tokens,word_to_ix)
print("3.\tTraining Data substituted with UNK!")

sentence= []
for sent in training_data:
     sentence.append(sent[:50])
padded_sentence = sentence_to_padded_sentence(sentence, word_to_ix)
print("4.\tPadded Sentences Generated!")

batch_size = 1
input_channel = 50 #vocab size
vocab_size = len(word_to_ix) 
embedding_dim = 200 
output_channel = 50
kernel_size = [20,15,10]
Feature_layer1 = embedding_dim - kernel_size[0] + 1
Feature_layer2 = Feature_layer1 - kernel_size[1] + 1
Feature_layer3 = Feature_layer2 - kernel_size[2] + 1
feature_linear = Feature_layer3 * input_channel

#Parameters for LSTM
hidden_dim = 128
dropout = 0.25, 
#recurrent_dropout = 0.3

model = MIMCT(input_channel,vocab_size,word_to_ix,output_channel,embedding_dim,hidden_dim,kernel_size,feature_linear, word_vector_list).to(cuda)
print("5.\tModel Generated!")
loss_function = nn.CrossEntropyLoss()
#Adam Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay = 1e-6)
training_data = padded_sentence

# %%
for epoch in range(15):  # running for 20 epoch
    train_sentence_losses = []
    dev_sentence_losses = []
    print("Epoch:", epoch)
    print("\nTraining Phase:")
    #for sentence in training_data:
    for index, sentence in enumerate(training_data):
        model.zero_grad()
        targets = tags[index]
        sentence_in = torch.tensor(sentence, dtype=torch.long).to(cuda)
        targets = prepare_sequence_tags(targets, tag_to_ix)
        tag_scores = model(sentence_in)
        loss = loss_function(tag_scores.cpu(), targets.cpu())
        train_sentence_losses.append(loss.item())
        loss.backward()
        optimizer.step()
    final_train_loss = sum(train_sentence_losses)/len(train_sentence_losses)
    print("Train Loss:", final_train_loss)

# %% [markdown]
# # Hinglish Part

# %%
Hindi_dict = "Hindi_English_dict.csv"
H_dict = pd.read_csv(Hindi_dict,names = ['Hindi','English'],encoding='UTF-8')

HE_dict_F = "HE_dictionary_functions.csv"
H_dict_F = pd.read_csv(HE_dict_F,names = ['Hindi','English'],encoding='UTF-8')
H_dict_F['Hindi'] = H_dict_F['Hindi'].str.strip()
H_dict_F['English'] = H_dict_F['English'].str.strip()
H_hindi_F = np.asarray(H_dict_F['Hindi'])
H_english_F = np.asarray(H_dict_F['English'])


H_dict['Hindi'] = H_dict['Hindi'].str.strip()
H_dict['English'] = H_dict['English'].str.strip()
H_hindi = np.asarray(H_dict['Hindi'])
H_english = np.asarray(H_dict['English'])

HE_dict = dict(zip(H_hindi,H_english))
H_dict_F = dict(zip(H_hindi_F,H_english_F))

EH_dict = {v:k for k, v in HE_dict.items()}
EH_dict_F = {v:k for k, v in H_dict_F.items()}


Hindi_text  = "hindi/agr_hi_train.csv"
df1 = pd.read_csv(Hindi_text,names = ['source','comment','annotation'],encoding='UTF-8')
df1['comment'] = df1.comment.str.strip()   # removing spaces
hindi_comments = np.asarray(df1['comment'])    # dividing the dataframe into comments and tags and converting to array
hindi_tags = np.asarray(df1['annotation'])
print((hindi_comments[1])) 
processed_Hindi_tokens = []
for comment in hindi_comments:
#    comment = "Also see ....hw ur RSS activist caught in Burkha .... throwing beef in d holy temples...https://www.google.co.in/amp/www.india.com/news/india/burkha-clad-rss-activist-caught-throwing-beef-at-temple-pictures-go-viral-on-facebook-593154/amp/,NAGfacebook_corpus_msr_403402,On the death of 2 jawans in LOC CROSS FIRING"
#    comment = comment.lower()   #lower casing each tweets
    Digit_REMOVAL = re.sub(r'[0-9]+', '',str(comment)) #removal of numbers 
    URL_REMOVAL = re.sub(r"http\S+", "", Digit_REMOVAL) # removal of URLS
    Emoji_removal = remove_emoji(URL_REMOVAL)
    Emoji_removal = Emoji_removal.lower()
    if (isEnglish(Emoji_removal) == True):
        Emoji_removal = re.sub(r'[^\w\s]','',Emoji_removal)# removal of punctuation and tokenizing
    processed_Hindi_tokens.append(word_tokenize(Emoji_removal))
processed_Hindi_tokens[0]
processed_Hindi_tokens[11]
processed_Hindi_tokens[6]
processed_Hindi_tokens[11]

# %%
#-----------Transliteration and translation
transliteration_dict = "transliterations.hi-en.csv"
t_dict = pd.read_csv(transliteration_dict,names = ['Hinglish','Hindi'],encoding='UTF-8',sep='\t')
t_dict['Hinglish'] = t_dict['Hinglish'].str.strip()
t_dict['Hindi'] = t_dict['Hindi'].str.strip()
t_dict = np.asarray(t_dict)

#--------------profanity dictionary
profanity_dict = "ProfanityText.txt"
P_dict = pd.read_csv(profanity_dict,names = ['Hinglish','English'],encoding='UTF-8',sep='\t')
P_dict['Hinglish'] = P_dict['Hinglish'].str.strip()
P_dict['English'] = P_dict['English'].str.strip()
P_dict = np.asarray(P_dict)


print(t_dict)
processed_Hindi_tokens[4]
for i in range(0,len(processed_Hindi_tokens)):
    print(i)
    for j in range (0,len(processed_Hindi_tokens[i])):
        flag = 0
        Str1 = (processed_Hindi_tokens[i][j])
        max_ratio = 60
        max_ratio_P = 75   #needs to be adjusted
        if (Str1 in EH_dict): # check whether the values exists in english dictionary or not.
            continue;
        for l in range(0,len(P_dict)):
            Str2 = P_dict[l][0]
            Ratiostr1 = fuzz.ratio(Str1,Str2)
            if (Ratiostr1 >= max_ratio_P):
                print(Ratiostr1)
                max_ratio_P = Ratiostr1
                processed_Hindi_tokens[i][j] = P_dict[l][1]
                flag = 1 
                print(flag)
                break;
        for p in EH_dict_F:
            Ratiostr1 = fuzz.ratio(Str1,str(p))
            if(Ratiostr1 >= 98):
                flag = 1
                break;
        if (flag == 1):
            continue;
        
        else:
            for k in range(0,len(t_dict)):
                Str2 = t_dict[k][0]
                Ratiostr1 = fuzz.ratio(Str1,Str2)
                if (Ratiostr1 > max_ratio):
                    max_ratio = Ratiostr1
                    processed_Hindi_tokens[i][j] = t_dict[k][1]
processed_Hindi_tokens[0]
processed_Hindi_tokens[1]
(processed_tokens[12])

# %%
#we already have processed hindi tokens dont need to run the above cell just run the below cell
processed_Hindi_tokens = pd.read_csv("ProcessedHinditokensfinal.csv",sep=",")
#processed_Hindi_tokens = translate_hindi_back_to_English(processed_Hindi_tokens, HE_dict, H_dict_F)
processed_Hindi_tokens = np.asarray(processed_Hindi_tokens)
lis = []
for i in processed_Hindi_tokens:
    lisT = []
    for j in i:
        if (str(j) == 'nan'):
            continue
        else:
            lisT.append(j)
    lis.append(lisT)
processed_Hindi_tokens = lis

# %%
Hindi_dict = "Hindi_English_dict.csv"
H_dict = pd.read_csv(Hindi_dict,names = ['Hindi','English'],encoding='UTF-8')

HE_dict_F = "HE_dictionary_functions.csv"
H_dict_F = pd.read_csv(HE_dict_F,names = ['Hindi','English'],encoding='UTF-8')
H_dict_F['Hindi'] = H_dict_F['Hindi'].str.strip()
H_dict_F['English'] = H_dict_F['English'].str.strip()
H_hindi_F = np.asarray(H_dict_F['Hindi'])
H_english_F = np.asarray(H_dict_F['English'])


H_dict['Hindi'] = H_dict['Hindi'].str.strip()
H_dict['English'] = H_dict['English'].str.strip()
H_hindi = np.asarray(H_dict['Hindi'])
H_english = np.asarray(H_dict['English'])

HE_dict = dict(zip(H_hindi,H_english))
H_dict_F = dict(zip(H_hindi_F,H_english_F))

EH_dict = {v:k for k, v in HE_dict.items()}
EH_dict_F = {v:k for k, v in H_dict_F.items()}


for i in range(0,len(processed_Hindi_tokens)):
    print(i)
    for j in range (0,len(processed_Hindi_tokens[i])):
        Str = processed_Hindi_tokens[i][j]
        if(Str in HE_dict):
            processed_Hindi_tokens[i][j] = HE_dict[Str]
        elif(Str in H_dict_F):
            processed_Hindi_tokens[i][j] = H_dict_F[Str]
            
processed_Hindi_tokens[3]

# %%
testing_data = utils.substitute_with_UNK_for_TEST(processed_Hindi_tokens,word_to_ix)
#do tags = hindi_tags

# %%
#just call the testing lookps after this

# %%
#DEV
f = "./english/agr_en_dev.csv"
dev_processed_tokens, dev_tags = get_processed_tokens_for_english_tweets(f)
# Out:
# 3001
# 3001

# %%
f = "english/agr_en_train.csv"
processed_tokens, tags = get_processed_tokens_for_english_tweets(f)
# Out:
# 11999
# 11999

# %%
processed_Hindi_tokens = pd.read_csv("hindi_tokens_translated_to_English_list.csv", sep="\s+")
#processed_Hindi_tokens = translate_hindi_back_to_English(processed_Hindi_tokens, HE_dict, H_dict_F)

# %%
processed_Hindi_tokens

# %%
word_to_ix = {}
ix_to_word = {}
tag_to_ix = {}
ix_to_tag = {}
word_to_ix = {"<PAD>":0}

# %%
#training_data = utils.substitute_with_UNK(processed_tokens,1)
# training_data = utils.substitute_with_UNK(processed_tokens,word_to_ix)
# testing_data = utils.substitute_with_UNK_for_TEST(processed_tokens,word_to_ix)
# print(len(training_data))

# %%
english_embeddings_fasttext = ft.get_words()

# %%
'UNK' in english_embeddings_fasttext
# Out:
# True

# %%
english_embeddings_fasttext = [word.lower() for word in english_embeddings_fasttext if not word in stopwords.words('english')]
english_embeddings_fasttext = [word.lower() for word in english_embeddings_fasttext if word.isalpha()]

# %%
data_vector = dict()
word_vector_list = []

# %%
#For PAD
dummy_list = []
dummy_list = np.zeros(200, dtype = float)
word_vector_list.append(dummy_list)

for i, word in enumerate(english_embeddings_fasttext):
    word_to_ix[word] = len(word_to_ix)
    word_vector_list.append(list(ft.get_word_vector(word)))
for tag in tags:
    if tag not in tag_to_ix:
        tag_to_ix[tag] = len(tag_to_ix)
        ix_to_tag[tag_to_ix[tag]] = tag

# word_to_ix["UNK"] = len(word_to_ix)

#For UNK
# word_vector_list.append(dummy_list)
word_vector_list = np.asarray(word_vector_list)

# %%
del ft

# %%
# for sent in training_data:
#     for word in sent:
#         if word not in word_to_ix:
#             word_to_ix[word] = len(word_to_ix)
#             ix_to_word[word_to_ix[word]] = word
# for tag in tags:
#     if tag not in tag_to_ix:
#         tag_to_ix[tag] = len(tag_to_ix)
#         ix_to_tag[tag_to_ix[tag]] = tag

# sentence= []
# for sent in training_data:
#      sentence.append(sent[:50])

# %%
training_data = utils.substitute_with_UNK_for_TEST(processed_tokens,word_to_ix)
#testing_data = utils.substitute_with_UNK_for_TEST(processed_tokens,word_to_ix)

# %%
#DEV
dev_data = utils.substitute_with_UNK_for_TEST(dev_processed_tokens,word_to_ix)

# %%
test_sentence = []
for sent in testing_data:
     test_sentence.append(sent[:50])

# %%
sentence= []
for sent in training_data:
     sentence.append(sent[:50])
padded_sentence = sentence_to_padded_sentence(sentence, word_to_ix)
#test_padded_sentence = sentence_to_padded_sentence(test_sentence, word_to_ix)

# %%
#DEV
dev_sentence= []
for sent in dev_data:
     dev_sentence.append(sent[:50])
        
dev_padded_sentence = sentence_to_padded_sentence(dev_sentence, word_to_ix)

# %%
#DEV
dev_data = dev_padded_sentence

# %%
class MIMCT(nn.Module):   
    def __init__(self,input_channel,vocab_size,word_to_ix,output_channel,embedding_dim,hidden_dim,kernel_size,feature_linear, word_vector_list):
        super(MIMCT, self).__init__()
        
#         self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
#         self.word_embeddings.weight.data.copy_(torch.from_numpy(word_vector_list))
        self.word_embeddings = nn.Embedding.from_pretrained(torch.from_numpy(word_vector_list))
        
        self.CNN_Layers = nn.Sequential( 
            nn.Conv1d(input_channel, output_channel,kernel_size[0], stride=1),
            nn.Conv1d(input_channel, output_channel, kernel_size[1], stride=1),
            nn.Conv1d(input_channel, output_channel, kernel_size[2], stride=1),
            nn.Flatten(),nn.Dropout(p=0.25),
            nn.Linear(feature_linear, 64),
            nn.ReLU(),
            nn.Linear(64, 3),
            nn.Softmax()
            )
        
        
        #create LSTM.
        #self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)
        self.hidden2tag = nn.Linear(hidden_dim,3)
        self.dropout = nn.Dropout(p=0.20)
        self.softmax = nn.Softmax()
        self.sigmoid = nn.Sigmoid()
        self.maxpool = nn.MaxPool1d(kernel_size=3, stride=1)
        self.linear = nn.Linear(50+1,3)
    def forward(self,x):
      #  y = self.LSTM_Layers(x)
#         print(x)
        embeds = self.word_embeddings(x)
#         embeds = embeds.type(torch.DoubleTensor)
        embeds= embeds.float()
        embeds_cnn = embeds.view(1,embeds.size(0),embeds.size(1))
        cnn_output = self.CNN_Layers(embeds_cnn)
        
        lstm_out, _ = self.lstm(embeds.view(len(x), 1, -1))
        lstm_out= self.dropout(lstm_out)
        tag_space = self.hidden2tag(lstm_out.view(len(x), -1))
        
        lstm_output = self.sigmoid(tag_space)
        #concat the outputs the compile layer with categorical cross-entropy the loss function,
        lstm_output = lstm_output.view(lstm_output.size(0),-1)
        cnn_output = cnn_output.view(cnn_output.size(0),-1)
        X = torch.cat((lstm_output,cnn_output))
        X = X.view(1,X.size(0),X.size(1))
        X = self.maxpool(X)
        X = self.linear(X.view(X.size(2), -1))
        X = self.softmax(X)
#         print(X)
        return X

# %%
batch_size = 1
input_channel = 10 #vocab size
vocab_size = len(word_to_ix) 
embedding_dim = 200 
output_channel = 10
kernel_size = [20,15,10]
Feature_layer1 = embedding_dim - kernel_size[0] + 1
Feature_layer2 = Feature_layer1 - kernel_size[1] + 1
Feature_layer3 = Feature_layer2 - kernel_size[2] + 1
feature_linear = Feature_layer3 * input_channel

# %%
batch_size = 1
input_channel = 50 #vocab size
vocab_size = len(word_to_ix) 
embedding_dim = 200 
output_channel = 50
kernel_size = [20,15,10]
Feature_layer1 = embedding_dim - kernel_size[0] + 1
Feature_layer2 = Feature_layer1 - kernel_size[1] + 1
Feature_layer3 = Feature_layer2 - kernel_size[2] + 1
feature_linear = Feature_layer3 * input_channel

#Parameters for LSTM
hidden_dim = 128
dropout = 0.25, 
#recurrent_dropout = 0.3

model = MIMCT(input_channel,vocab_size,word_to_ix,output_channel,embedding_dim,hidden_dim,kernel_size,feature_linear, word_vector_list).to(cuda)
loss_function = nn.CrossEntropyLoss()
#Adam Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay = 1e-6)
original_data = training_data
training_data = padded_sentence
dev_data = dev_padded_sentence
# sentence1 = training_data[0]

# %%
len(list(word_to_ix.keys()))

# %%
word_to_ix["UNK"]

# %%
# %%capture cap --no-stderr

for epoch in range(15):  # running for 20 epoch
    train_sentence_losses = []
    dev_sentence_losses = []
    print("Epoch:", epoch)
    print("\nTraining Phase:")
    #for sentence in training_data:
    for index, sentence in enumerate(training_data):
        model.zero_grad()
        targets = tags[index]
        sentence_in = torch.tensor(sentence, dtype=torch.long).to(cuda)
        targets = prepare_sequence_tags(targets, tag_to_ix)
        tag_scores = model(sentence_in)
        loss = loss_function(tag_scores.cpu(), targets.cpu())
        train_sentence_losses.append(loss.item())
        loss.backward()
        optimizer.step()
    final_train_loss = sum(train_sentence_losses)/len(train_sentence_losses)
    print("Train Loss:", final_train_loss)
    
# with open('epoch_cell_output.txt', 'w') as f:
#     f.write(cap.stdout)
# Out:
# Epoch: 0
#
# Training Phase:
# <ipython-input-21-63fc7ae221d9>:51: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   X = self.softmax(X)
# Train Loss: 1.0569113525502611
# Epoch: 1
#
# Training Phase:
# Train Loss: 1.023985328460914
# Epoch: 2
#
# Training Phase:
# Train Loss: 1.0010143753856169
# Epoch: 3
#
# Training Phase:
# Train Loss: 0.9870225362941041
# Epoch: 4
#
# Training Phase:
# Train Loss: 0.9700971282673971
# Epoch: 5
#
# Training Phase:
# Train Loss: 0.9510965908663562
# Epoch: 6
#
# Training Phase:
# Train Loss: 0.9355709457290163
# Epoch: 7
#
# Training Phase:
# Train Loss: 0.9332014834824199
# Epoch: 8
#
# Training Phase:
# Train Loss: 0.9130131625087969
# Epoch: 9
#
# Training Phase:
# Train Loss: 0.8914501574230409
# Epoch: 10
#
# Training Phase:
# Train Loss: 0.8974563407891988
# Epoch: 11
#
# Training Phase:
# Train Loss: 0.8640565078589745
# Epoch: 12
#
# Training Phase:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9e70f8859525> in <module>
#      10         model.zero_grad()
#      11         targets = tags[index]
# ---> 12         sentence_in = torch.tensor(sentence, dtype=torch.long).to(cuda)
#      13         targets = prepare_sequence_tags(targets, tag_to_ix)
#      14         tag_scores = model(sentence_in)
#
# KeyboardInterrupt:

# %%
import time

# CODE TO IMPLEMENT EARLY STOPPING
PATIENCE = 200
counter = 0
minLoss = float('inf')

for epoch in range(200):  # running for 20 epoch
    train_sentence_losses = []
    dev_sentence_losses = []
    print("\nEpoch:", epoch)
    print("\nTraining Phase:")
    start_time = time.time()
    #for sentence in training_data:
    for index, sentence in enumerate(training_data):
        model.zero_grad()
        targets = tags[index]
        sentence_in = torch.tensor(sentence, dtype=torch.long).to(cuda)
        targets = prepare_sequence_tags(targets, tag_to_ix)
        tag_scores = model(sentence_in)
        loss = loss_function(tag_scores.cpu(), targets.cpu())
        train_sentence_losses.append(loss.item())
#         optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    final_train_loss = sum(train_sentence_losses)/len(train_sentence_losses)
    print("Train Loss:", final_train_loss)
    
    with torch.no_grad():
        print("\nTesting Phase:")
        for index, sentence in enumerate(dev_data):
            targets = tags[index]
            sentence_in = torch.tensor(sentence, dtype=torch.long).to(cuda)
            targets = prepare_sequence_tags(targets, tag_to_ix)
            # Step 3. Run our forward pass.
            tag_scores = model(sentence_in)
            # Step 4. Compute the loss, gradients, and update the parameters by
            #  calling optimizer.step()
            dev_loss = loss_function(tag_scores.cpu(), targets.cpu())
            dev_sentence_losses.append(dev_loss.item())
        final_dev_loss = sum(dev_sentence_losses)/len(dev_sentence_losses)
        print("Dev Loss:", final_dev_loss)
        
        end_time = time.time()
        print("Total Epoch Time: ", end_time - start_time)
        
        if final_dev_loss < minLoss:
#             torch.save(model.state_dict(), "./MIMCT_SAIF.pth")
            print("\nCurrent loss < Previous Loss")
            minLoss = final_dev_loss
            print("minLoss set to = ", minLoss)
            counter = 0
            print("Counter reset\n")
            
        if final_dev_loss > minLoss:
            print("\nCurrent loss > Min Loss")
            counter += 1
            print("counter = ", counter)
            if counter == PATIENCE:
                print("counter = patience")
                FINALEPOCH = epoch-counter
                break

print("\nFinal Epoch = ", FINALEPOCH)
# Out:
# Epoch: 0
#
# Training Phase:
# /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/ipykernel/__main__.py:51: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# Train Loss: 1.0566565986672722
#
# Testing Phase:
# Dev Loss: 1.0886340561369108
# Total Epoch Time:  115.81469678878784
#
# Current loss < Previous Loss
# minLoss set to =  1.0886340561369108
# Counter reset
#
#
# Epoch: 1
#
# Training Phase:
# Train Loss: 1.0241142910305128
#
# Testing Phase:
# Dev Loss: 1.1103812719098491
# Total Epoch Time:  116.88839817047119
#
# Current loss > Min Loss
# counter =  1
#
# Epoch: 2
#
# Training Phase:
# Train Loss: 0.9960188889604815
#
# Testing Phase:
# Dev Loss: 1.1106647641132052
# Total Epoch Time:  115.1478419303894
#
# Current loss > Min Loss
# counter =  2
#
# Epoch: 3
#
# Training Phase:
# Train Loss: 0.9756463829582259
#
# Testing Phase:
# Dev Loss: 1.1162628898696874
# Total Epoch Time:  115.34320831298828
#
# Current loss > Min Loss
# counter =  3
#
# Epoch: 4
#
# Training Phase:
# Train Loss: 0.9556011035696885
#
# Testing Phase:
# Dev Loss: 1.1288023805546785
# Total Epoch Time:  115.2480673789978
#
# Current loss > Min Loss
# counter =  4
#
# Epoch: 5
#
# Training Phase:
# Train Loss: 0.9442504574551325
#
# Testing Phase:
# Dev Loss: 1.1519146314544386
# Total Epoch Time:  116.33401584625244
#
# Current loss > Min Loss
# counter =  5
#
# Epoch: 6
#
# Training Phase:
# Train Loss: 0.9368443339603605
#
# Testing Phase:
# Dev Loss: 1.1238469603219774
# Total Epoch Time:  116.29318189620972
#
# Current loss > Min Loss
# counter =  6
#
# Epoch: 7
#
# Training Phase:
# Train Loss: 0.9217030060610202
#
# Testing Phase:
# Dev Loss: 1.141107862093416
# Total Epoch Time:  116.56157946586609
#
# Current loss > Min Loss
# counter =  7
#
# Epoch: 8
#
# Training Phase:
# Train Loss: 0.9114667409876503
#
# Testing Phase:
# Dev Loss: 1.1520334891341837
# Total Epoch Time:  116.84177350997925
#
# Current loss > Min Loss
# counter =  8
#
# Epoch: 9
#
# Training Phase:
# Train Loss: 0.9040858947403163
#
# Testing Phase:
# Dev Loss: 1.151644671233405
# Total Epoch Time:  115.5851469039917
#
# Current loss > Min Loss
# counter =  9
#
# Epoch: 10
#
# Training Phase:
# Train Loss: 0.8826520116351646
#
# Testing Phase:
# Dev Loss: 1.1580958688151872
# Total Epoch Time:  115.2810161113739
#
# Current loss > Min Loss
# counter =  10
#
# Epoch: 11
#
# Training Phase:
# Train Loss: 0.8781055100848947
#
# Testing Phase:
# Dev Loss: 1.1694753872120789
# Total Epoch Time:  115.68147993087769
#
# Current loss > Min Loss
# counter =  11
#
# Epoch: 12
#
# Training Phase:
# Train Loss: 0.8880227699618766
#
# Testing Phase:
# Dev Loss: 1.160052813994253
# Total Epoch Time:  115.62654972076416
#
# Current loss > Min Loss
# counter =  12
#
# Epoch: 13
#
# Training Phase:
# Train Loss: 0.8651307480952592
#
# Testing Phase:
# Dev Loss: 1.1655735942333072
# Total Epoch Time:  115.15616917610168
#
# Current loss > Min Loss
# counter =  13
#
# Epoch: 14
#
# Training Phase:
# Train Loss: 0.8535051330972467
#
# Testing Phase:
# Dev Loss: 1.1640960142359023
# Total Epoch Time:  115.836674451828
#
# Current loss > Min Loss
# counter =  14
#
# Epoch: 15
#
# Training Phase:
# Train Loss: 0.8443856198188215
#
# Testing Phase:
# Dev Loss: 1.169536155388777
# Total Epoch Time:  115.39109206199646
#
# Current loss > Min Loss
# counter =  15
#
# Epoch: 16
#
# Training Phase:
# Train Loss: 0.8321971012479177
#
# Testing Phase:
# Dev Loss: 1.178508555916936
# Total Epoch Time:  115.3148295879364
#
# Current loss > Min Loss
# counter =  16
#
# Epoch: 17
#
# Training Phase:
# Train Loss: 0.8259112173363073
#
# Testing Phase:
# Dev Loss: 1.188842661596862
# Total Epoch Time:  114.87768363952637
#
# Current loss > Min Loss
# counter =  17
#
# Epoch: 18
#
# Training Phase:
# Train Loss: 0.8139036191891745
#
# Testing Phase:
# Dev Loss: 1.1731986707347666
# Total Epoch Time:  115.88047623634338
#
# Current loss > Min Loss
# counter =  18
#
# Epoch: 19
#
# Training Phase:
# Train Loss: 0.8086456711495535
#
# Testing Phase:
# Dev Loss: 1.174505149809689
# Total Epoch Time:  116.45756459236145
#
# Current loss > Min Loss
# counter =  19
#
# Epoch: 20
#
# Training Phase:
# Train Loss: 0.8019494932486083
#
# Testing Phase:
# Dev Loss: 1.175217390298764
# Total Epoch Time:  115.74515748023987
#
# Current loss > Min Loss
# counter =  20
#
# Epoch: 21
#
# Training Phase:
# Train Loss: 0.7961880575568391
#
# Testing Phase:
# Dev Loss: 1.1769668467042447
# Total Epoch Time:  117.95425009727478
#
# Current loss > Min Loss
# counter =  21
#
# Epoch: 22
#
# Training Phase:
# Train Loss: 0.7910577731834311
#
# Testing Phase:
# Dev Loss: 1.1736216615613642
# Total Epoch Time:  116.13211035728455
#
# Current loss > Min Loss
# counter =  22
#
# Epoch: 23
#
# Training Phase:
# Train Loss: 0.7821337062971365
#
# Testing Phase:
# Dev Loss: 1.1759249859950973
# Total Epoch Time:  116.13004803657532
#
# Current loss > Min Loss
# counter =  23
#
# Epoch: 24
#
# Training Phase:
# Train Loss: 0.7858745347351738
#
# Testing Phase:
# Dev Loss: 1.1785447876956294
# Total Epoch Time:  116.79804229736328
#
# Current loss > Min Loss
# counter =  24
#
# Epoch: 25
#
# Training Phase:
# Train Loss: 0.7804972978222021
#
# Testing Phase:
# Dev Loss: 1.1830057499012285
# Total Epoch Time:  114.94251108169556
#
# Current loss > Min Loss
# counter =  25
#
# Epoch: 26
#
# Training Phase:
# Train Loss: 0.7738559946227803
#
# Testing Phase:
# Dev Loss: 1.1827990474481656
# Total Epoch Time:  114.70949816703796
#
# Current loss > Min Loss
# counter =  26
#
# Epoch: 27
#
# Training Phase:
# Train Loss: 0.7747767015252176
#
# Testing Phase:
# Dev Loss: 1.1801479839952895
# Total Epoch Time:  114.30434203147888
#
# Current loss > Min Loss
# counter =  27
#
# Epoch: 28
#
# Training Phase:
# Train Loss: 0.7705090905896961
#
# Testing Phase:
# Dev Loss: 1.1802820427463039
# Total Epoch Time:  116.78982472419739
#
# Current loss > Min Loss
# counter =  28
#
# Epoch: 29
#
# Training Phase:
# Train Loss: 0.7693407547872299
#
# Testing Phase:
# Dev Loss: 1.1788221819128286
# Total Epoch Time:  116.33352375030518
#
# Current loss > Min Loss
# counter =  29
#
# Epoch: 30
#
# Training Phase:
# Train Loss: 0.7630310424447745
#
# Testing Phase:
# Dev Loss: 1.1842295438478248
# Total Epoch Time:  114.6500518321991
#
# Current loss > Min Loss
# counter =  30
#
# Epoch: 31
#
# Training Phase:
# Train Loss: 0.7609205776844952
#
# Testing Phase:
# Dev Loss: 1.174648376255582
# Total Epoch Time:  114.40277862548828
#
# Current loss > Min Loss
# counter =  31
#
# Epoch: 32
#
# Training Phase:
# Train Loss: 0.7601009449250241
#
# Testing Phase:
# Dev Loss: 1.185515586811874
# Total Epoch Time:  115.28870582580566
#
# Current loss > Min Loss
# counter =  32
#
# Epoch: 33
#
# Training Phase:
# Train Loss: 0.7619538544932944
#
# Testing Phase:
# Dev Loss: 1.1762621758858867
# Total Epoch Time:  116.28338932991028
#
# Current loss > Min Loss
# counter =  33
#
# Epoch: 34
#
# Training Phase:
# Train Loss: 0.7521640588138608
#
# Testing Phase:
# Dev Loss: 1.1813297062585926
# Total Epoch Time:  115.50479364395142
#
# Current loss > Min Loss
# counter =  34
#
# Epoch: 35
#
# Training Phase:
# Train Loss: 0.7514636574143996
#
# Testing Phase:
# Dev Loss: 1.182223279668426
# Total Epoch Time:  115.07040309906006
#
# Current loss > Min Loss
# counter =  35
#
# Epoch: 36
#
# Training Phase:
# Train Loss: 0.7487015591749441
#
# Testing Phase:
# Dev Loss: 1.176389683846115
# Total Epoch Time:  115.6476616859436
#
# Current loss > Min Loss
# counter =  36
#
# Epoch: 37
#
# Training Phase:
# Train Loss: 0.7440939883121164
#
# Testing Phase:
# Dev Loss: 1.1747984846049013
# Total Epoch Time:  115.2048077583313
#
# Current loss > Min Loss
# counter =  37
#
# Epoch: 38
#
# Training Phase:
# Train Loss: 0.7441908924447883
#
# Testing Phase:
# Dev Loss: 1.1806883624854465
# Total Epoch Time:  116.54607939720154
#
# Current loss > Min Loss
# counter =  38
#
# Epoch: 39
#
# Training Phase:
# Train Loss: 0.7449924428121817
#
# Testing Phase:
# Dev Loss: 1.1734227138692161
# Total Epoch Time:  117.14121437072754
#
# Current loss > Min Loss
# counter =  39
#
# Epoch: 40
#
# Training Phase:
# Train Loss: 0.7407623450650167
#
# Testing Phase:
# Dev Loss: 1.1715518763286994
# Total Epoch Time:  116.47359538078308
#
# Current loss > Min Loss
# counter =  40
#
# Epoch: 41
#
# Training Phase:
# Train Loss: 0.736032299185129
#
# Testing Phase:
# Dev Loss: 1.1748351015396334
# Total Epoch Time:  116.31903100013733
#
# Current loss > Min Loss
# counter =  41
#
# Epoch: 42
#
# Training Phase:
# Train Loss: 0.7385486583429949
#
# Testing Phase:
# Dev Loss: 1.175328520845072
# Total Epoch Time:  114.70420217514038
#
# Current loss > Min Loss
# counter =  42
#
# Epoch: 43
#
# Training Phase:
# Train Loss: 0.7385475413135036
#
# Testing Phase:
# Dev Loss: 1.174182658769893
# Total Epoch Time:  116.49267935752869
#
# Current loss > Min Loss
# counter =  43
#
# Epoch: 44
#
# Training Phase:
# Train Loss: 0.7389451076372612
#
# Testing Phase:
# Dev Loss: 1.1681895709085448
# Total Epoch Time:  116.45764422416687
#
# Current loss > Min Loss
# counter =  44
#
# Epoch: 45
#
# Training Phase:
# Train Loss: 0.73579262193913
#
# Testing Phase:
# Dev Loss: 1.1698712990586657
# Total Epoch Time:  114.65741395950317
#
# Current loss > Min Loss
# counter =  45
#
# Epoch: 46
#
# Training Phase:
# Train Loss: 0.7334890865029787
#
# Testing Phase:
# Dev Loss: 1.1797495114529224
# Total Epoch Time:  116.51929092407227
#
# Current loss > Min Loss
# counter =  46
#
# Epoch: 47
#
# Training Phase:
# Train Loss: 0.7286002424739084
#
# Testing Phase:
# Dev Loss: 1.1723548898455383
# Total Epoch Time:  115.36226201057434
#
# Current loss > Min Loss
# counter =  47
#
# Epoch: 48
#
# Training Phase:
# Train Loss: 0.7343003844278972
#
# Testing Phase:
# Dev Loss: 1.1758629787329713
# Total Epoch Time:  116.67832684516907
#
# Current loss > Min Loss
# counter =  48
#
# Epoch: 49
#
# Training Phase:
# Train Loss: 0.73003684975662
#
# Testing Phase:
# Dev Loss: 1.1785716701650255
# Total Epoch Time:  116.97753357887268
#
# Current loss > Min Loss
# counter =  49
#
# Epoch: 50
#
# Training Phase:
# Train Loss: 0.7308440977349382
#
# Testing Phase:
# Dev Loss: 1.1782715388911043
# Total Epoch Time:  115.33091473579407
#
# Current loss > Min Loss
# counter =  50
#
# Epoch: 51
#
# Training Phase:
# Train Loss: 0.725074705545858
#
# Testing Phase:
# Dev Loss: 1.1804378141923095
# Total Epoch Time:  115.78858256340027
#
# Current loss > Min Loss
# counter =  51
#
# Epoch: 52
#
# Training Phase:
# Train Loss: 0.7252983406877823
#
# Testing Phase:
# Dev Loss: 1.1750950013665666
# Total Epoch Time:  114.3936357498169
#
# Current loss > Min Loss
# counter =  52
#
# Epoch: 53
#
# Training Phase:
# Train Loss: 0.7250564278776581
#
# Testing Phase:
# Dev Loss: 1.1704810550315345
# Total Epoch Time:  116.42594051361084
#
# Current loss > Min Loss
# counter =  53
#
# Epoch: 54
#
# Training Phase:
# Train Loss: 0.7241495470919602
#
# Testing Phase:
# Dev Loss: 1.1675703067137615
# Total Epoch Time:  117.1398720741272
#
# Current loss > Min Loss
# counter =  54
#
# Epoch: 55
#
# Training Phase:
# Train Loss: 0.72211487526317
#
# Testing Phase:
# Dev Loss: 1.1692174441891485
# Total Epoch Time:  116.10961508750916
#
# Current loss > Min Loss
# counter =  55
#
# Epoch: 56
#
# Training Phase:
# Train Loss: 0.7228419781227948
#
# Testing Phase:
# Dev Loss: 1.1735197943633733
# Total Epoch Time:  115.62831568717957
#
# Current loss > Min Loss
# counter =  56
#
# Epoch: 57
#
# Training Phase:
# Train Loss: 0.722197881941299
#
# Testing Phase:
# Dev Loss: 1.1759204739175293
# Total Epoch Time:  114.77334594726562
#
# Current loss > Min Loss
# counter =  57
#
# Epoch: 58
#
# Training Phase:
# Train Loss: 0.7239734422555515
#
# Testing Phase:
# Dev Loss: 1.1748851085853196
# Total Epoch Time:  116.91824579238892
#
# Current loss > Min Loss
# counter =  58
#
# Epoch: 59
#
# Training Phase:
# Train Loss: 0.7181042987303452
#
# Testing Phase:
# Dev Loss: 1.1845444790604351
# Total Epoch Time:  115.5224928855896
#
# Current loss > Min Loss
# counter =  59
#
# Epoch: 60
#
# Training Phase:
# Train Loss: 0.7189511388517914
#
# Testing Phase:
# Dev Loss: 1.1736855669960662
# Total Epoch Time:  115.28820514678955
#
# Current loss > Min Loss
# counter =  60
#
# Epoch: 61
#
# Training Phase:
# Train Loss: 0.7202868406370646
#
# Testing Phase:
# Dev Loss: 1.1770139243832354
# Total Epoch Time:  115.96192121505737
#
# Current loss > Min Loss
# counter =  61
#
# Epoch: 62
#
# Training Phase:
# Train Loss: 0.7150938609598358
#
# Testing Phase:
# Dev Loss: 1.1706055788865133
# Total Epoch Time:  116.68691968917847
#
# Current loss > Min Loss
# counter =  62
#
# Epoch: 63
#
# Training Phase:
# Train Loss: 0.7163591492284347
#
# Testing Phase:
# Dev Loss: 1.180857013559707
# Total Epoch Time:  115.1179051399231
#
# Current loss > Min Loss
# counter =  63
#
# Epoch: 64
#
# Training Phase:
# Train Loss: 0.7127641945324775
#
# Testing Phase:
# Dev Loss: 1.1763670815701726
# Total Epoch Time:  116.72870254516602
#
# Current loss > Min Loss
# counter =  64
#
# Epoch: 65
#
# Training Phase:
# Train Loss: 0.7167663156653417
#
# Testing Phase:
# Dev Loss: 1.177100277451506
# Total Epoch Time:  115.38867354393005
#
# Current loss > Min Loss
# counter =  65
#
# Epoch: 66
#
# Training Phase:
# Train Loss: 0.7148792754213893
#
# Testing Phase:
# Dev Loss: 1.175397104857088
# Total Epoch Time:  116.86448788642883
#
# Current loss > Min Loss
# counter =  66
#
# Epoch: 67
#
# Training Phase:
# Train Loss: 0.7166123733747819
#
# Testing Phase:
# Dev Loss: 1.1742116652183316
# Total Epoch Time:  116.08155536651611
#
# Current loss > Min Loss
# counter =  67
#
# Epoch: 68
#
# Training Phase:
# Train Loss: 0.7148207191308644
#
# Testing Phase:
# Dev Loss: 1.175158379754
# Total Epoch Time:  116.16285991668701
#
# Current loss > Min Loss
# counter =  68
#
# Epoch: 69
#
# Training Phase:
# Train Loss: 0.7102819136385421
#
# Testing Phase:
# Dev Loss: 1.1815645040491747
# Total Epoch Time:  116.91456151008606
#
# Current loss > Min Loss
# counter =  69
#
# Epoch: 70
#
# Training Phase:
# Train Loss: 0.7111260316025984
#
# Testing Phase:
# Dev Loss: 1.1769473798789012
# Total Epoch Time:  116.38242864608765
#
# Current loss > Min Loss
# counter =  70
#
# Epoch: 71
#
# Training Phase:
# Train Loss: 0.7138573742675844
#
# Testing Phase:
# Dev Loss: 1.1847378685648384
# Total Epoch Time:  117.02144694328308
#
# Current loss > Min Loss
# counter =  71
#
# Epoch: 72
#
# Training Phase:
# Train Loss: 0.7121066294895508
#
# Testing Phase:
# Dev Loss: 1.1793026783910445
# Total Epoch Time:  114.94048309326172
#
# Current loss > Min Loss
# counter =  72
#
# Epoch: 73
#
# Training Phase:
# Train Loss: 0.7157927793863963
#
# Testing Phase:
# Dev Loss: 1.1886410935248426
# Total Epoch Time:  116.80479550361633
#
# Current loss > Min Loss
# counter =  73
#
# Epoch: 74
#
# Training Phase:
# Train Loss: 0.7108171439009892
#
# Testing Phase:
# Dev Loss: 1.1780055771268076
# Total Epoch Time:  115.5818727016449
#
# Current loss > Min Loss
# counter =  74
#
# Epoch: 75
#
# Training Phase:
# Train Loss: 0.7150729852215888
#
# Testing Phase:
# Dev Loss: 1.1868070739183931
# Total Epoch Time:  115.09916639328003
#
# Current loss > Min Loss
# counter =  75
#
# Epoch: 76
#
# Training Phase:
# Train Loss: 0.708162604873305
#
# Testing Phase:
# Dev Loss: 1.1771192363562961
# Total Epoch Time:  115.72404861450195
#
# Current loss > Min Loss
# counter =  76
#
# Epoch: 77
#
# Training Phase:
# Train Loss: 0.714516324831631
#
# Testing Phase:
# Dev Loss: 1.1703675233773572
# Total Epoch Time:  116.23069500923157
#
# Current loss > Min Loss
# counter =  77
#
# Epoch: 78
#
# Training Phase:
# Train Loss: 0.7073870226635278
#
# Testing Phase:
# Dev Loss: 1.170842507369357
# Total Epoch Time:  116.3544397354126
#
# Current loss > Min Loss
# counter =  78
#
# Epoch: 79
#
# Training Phase:
# Train Loss: 0.7051310256994091
#
# Testing Phase:
# Dev Loss: 1.177040351605026
# Total Epoch Time:  114.58880662918091
#
# Current loss > Min Loss
# counter =  79
#
# Epoch: 80
#
# Training Phase:
# Train Loss: 0.7060842306695985
#
# Testing Phase:
# Dev Loss: 1.1866713504281214
# Total Epoch Time:  116.04624080657959
#
# Current loss > Min Loss
# counter =  80
#
# Epoch: 81
#
# Training Phase:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-210a3f7763ec> in <module>
#      23 #         optimizer.zero_grad()
#      24         loss.backward()
# ---> 25         optimizer.step()
#      26     final_train_loss = sum(train_sentence_losses)/len(train_sentence_losses)
#      27     print("Train Loss:", final_train_loss)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      85         # Decay the first and second moment running average coefficient
#      86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#      89             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), "./model_v3_embedding_freezed_(15).pth")

# %%
model.load_state_dict(torch.load("./model_v1.pth"))

# %%
epoch

# %%
processed_Hindi_tokens

import csv

with open("hindi_tokens_translated_to_English_list.csv", "w", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerows(processed_Hindi_tokens)

# %%
def get_processed_testing_tokens_for_english_tweets():
    f = "agr_en_fb_test.csv"
    # preprocessing english tweets.
    #ingesting english csv file
    df = pd.read_csv(f,names = ['source','comment','annotation'],encoding='UTF-8')
    df['comment'] = df.comment.str.strip()   # removing spaces
    comments = np.asarray(df['comment'])    # dividing the dataframe into comments and tags and converting to array
    tags = np.asarray(df['annotation'])
    print((len(comments)))
    print(len(tags))
    stop_words = set(stopwords.words('english'))  #english stop words list
    processed_tokens = []
    for comment in comments:
    # comment = "Also see ....hw ur RSS activist caught in Burkha .... throwing beef in d holy temples...https://www.google.co.in/amp/www.india.com/news/india/burkha-clad-rss-activist-caught-throwing-beef-at-temple-pictures-go-viral-on-facebook-593154/amp/,NAGfacebook_corpus_msr_403402,On the death of 2 jawans in LOC CROSS FIRING"
        comment = comment.lower()   #lower casing each tweets
        Digit_REMOVAL = re.sub(r'[0-9]+', '',comment) #removal of numbers 
        URL_REMOVAL = re.sub(r"http\S+", "", Digit_REMOVAL) # removal of URLS
        tokenizer = nltk.RegexpTokenizer(r"\w+")   # removal of punctuation and tokenizing
        new_words = tokenizer.tokenize(URL_REMOVAL)
        sentence = []
        for word in new_words:
            if word not in stop_words:           #checking for stop words on each sentence
                sentence.append(word)
        processed_tokens.append(sentence)
    return processed_tokens

# %%
processed_tokens = get_processed_testing_tokens_for_english_tweets()

# %%
testing_data = utils.substitute_with_UNK_for_TEST(processed_tokens,word_to_ix)

# %%
test_sentence = []
for sent in testing_data:
     test_sentence.append(sent[:50])

# %%
test_padded_sentence = sentence_to_padded_sentence(test_sentence, word_to_ix)

# %%
testing_data = test_padded_sentence
with torch.no_grad():
	# this will be the file to write the outputs
    with open("mymodel_output.txt", 'w',encoding='UTF-8') as op:
        for instance in testing_data:
            # Convert the test sentence into a word ID tensor
            test_sentence_in=torch.tensor(instance, dtype=torch.long).to(cuda)

            tag_scores = model(test_sentence_in)

            # Find the tag with the highest probability in each position
            outputs = [int(np.argmax(ts)) for ts in tag_scores.cpu().detach().numpy()]
            # Prepare the output to be written in the same format as the test file (word|tag)
            formatted_output = ix_to_tag[outputs[0]]
            # Write the output
            op.write(formatted_output + '\n')
            
            print(outputs)
        print(len(test_data))

# %%
embeds_cnn
